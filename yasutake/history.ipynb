# %%
import pandas as pd
dfA=pd.read_csv("train_A.tsv", delimiter='\t')
dfB=pd.read_csv("train_B.tsv", delimiter='\t')
dfC=pd.read_csv("train_C.tsv", delimiter='\t')
dfD=pd.read_csv("train_D.tsv", delimiter='\t')
df_list=[dfA,dfB,dfC,dfD]

# %%
df =dfA.sort_values(by=["user_id","product_id","time_stamp"],ascending = [True,True,True])
df["Counts"] = df.groupby(["product_id","user_id","event_type"])["event_type"].transform('count')
a = df.duplicated(["product_id","user_id","event_type"],keep=False)
df  = df[a]
df = df.drop_duplicates(["user_id","product_id","event_type"])
df.ix[:,['user_id','product_id','event_type','Counts','time_stamp','ad']]
df[df.event_type == 3]
# Out:
# /Users/yasutakenaoki/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#            user_id  product_id  event_type  ad               time_stamp  \
# 876618   0000003_A  00012529_a           3   1  2017-04-01 03:03:13.048
# 952423   0000005_A  00011262_a           3   1  2017-04-12 07:15:05.926
# 952502   0000005_A  00011998_a           3   1  2017-04-24 06:51:10.932
# 2457833  0000032_A  00000247_a           3   1  2017-04-18 03:26:56.879
# 2457872  0000032_A  00001616_a           3   1  2017-04-18 15:02:29.592
# 2457911  0000032_A  00008651_a           3   1  2017-04-24 16:51:12.860
# 2457606  0000032_A  00008674_a           3   1  2017-04-18 03:50:27.775
# 2457891  0000032_A  00009339_a           3   1  2017-04-20 04:19:04.197
# ...

# %%
df =dfB.sort_values(by=["user_id","product_id","time_stamp"],ascending = [True,True,True])
df["Counts"] = df.groupby(["product_id","user_id","event_type"])["event_type"].transform('count')
a = df.duplicated(["product_id","user_id","event_type"],keep=False)
df  = df[a]
df = df.drop_duplicates(["user_id","product_id","event_type"])
df = df.ix[:,['user_id','product_id','event_type','Counts','time_stamp','ad']]
df[df.event_type == 3]
# Out:
# /Users/yasutakenaoki/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#            user_id  product_id  event_type  Counts               time_stamp  \
# 241976   0000007_B  00003978_b           3       2  2017-04-03 01:10:56.818
# 241947   0000007_B  00008188_b           3       2  2017-04-03 07:42:33.018
# 307694   0000009_B  00003788_b           3       2  2017-04-10 08:07:04.394
# 497386   0000015_B  00000744_b           3       2  2017-04-14 00:34:48.617
# 497379   0000015_B  00000841_b           3       2  2017-04-13 06:54:51.591
# 354310   0000032_B  00000046_b           3       2  2017-04-21 05:43:31.668
# 609739   0000038_B  00014456_b           3       2  2017-04-06 13:43:08.871
# ...

# %%
df =dfC.sort_values(by=["user_id","product_id","time_stamp"],ascending = [True,True,True])
df["Counts"] = df.groupby(["product_id","user_id","event_type"])["event_type"].transform('count')
a = df.duplicated(["product_id","user_id","event_type"],keep=False)
df  = df[a]
df = df.drop_duplicates(["user_id","product_id","event_type"])
df.ix[:,['user_id','product_id','event_type','Counts','time_stamp','ad']]
df[df.event_type == 3]
# Out:
# /Users/yasutakenaoki/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#            user_id  product_id  event_type  ad               time_stamp  \
# 831135   0001365_C  00273153_c           3   0  2017-04-23 12:59:56.634
# 633608   0001535_C  00139999_c           3   0  2017-04-08 13:01:43.250
# 1513662  0001841_C  00304388_c           3   0  2017-03-31 15:28:53.549
# 1518168  0001873_C  00135363_c           3   0  2017-04-22 14:36:58.556
# 1487438  0001886_C  00242956_c           3   0  2017-04-16 14:55:59.997
# 946134   0001965_C  00147399_c           3   1  2017-04-24 13:10:19.626
# 6123     0002214_C  00161377_c           3   0  2017-04-16 08:51:49.831
# 6118     0002214_C  00308507_c           3   0  2017-04-16 08:52:54.660
# ...

# %%
df =dfD.sort_values(by=["user_id","product_id","time_stamp"],ascending = [True,True,True])
df["Counts"] = df.groupby(["product_id","user_id","event_type"])["event_type"].transform('count')
a = df.duplicated(["product_id","user_id","event_type"],keep=False)
df  = df[a]
df = df.drop_duplicates(["user_id","product_id","event_type"])
df.ix[:,['user_id','product_id','event_type','Counts','time_stamp','ad']]
df[df.event_type == 3]
# Out:
# /Users/yasutakenaoki/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#            user_id  product_id  event_type  ad               time_stamp  \
# 2347959  0000410_D  00656949_d           3   0  2017-04-25 09:15:27.913
# 1094354  0005018_D  00341153_d           3   1  2017-04-27 06:54:14.797
# 2013233  0006278_D  00199807_d           3   1  2017-04-23 14:21:52.212
# 2013223  0006278_D  00334801_d           3   1  2017-04-18 02:33:27.199
# 789388   0010267_D  00185894_d           3   1  2017-04-07 00:10:36.010
# 789402   0010267_D  00577171_d           3   1  2017-04-10 15:59:05.711
# 626452   0013712_D  00087762_d           3   1  2017-04-06 13:00:56.030
# 1256512  0014834_D  00121082_d           3   1  2017-04-19 09:20:44.444
# ...

# %%
for df in df_list:
    df =df.sort_values(by=["user_id","product_id","time_stamp"],ascending = [True,True,True])
    df["Counts"] = df.groupby(["product_id","user_id","event_type"])["event_type"].transform('count')
    a = df.duplicated(["product_id","user_id","event_type"],keep=False)
    df  = df[a]
    df = df.drop_duplicates(["user_id","product_id","event_type"])
    df = df.ix[:,['user_id','product_id','event_type','Counts','time_stamp','ad']]
    df[df.event_type == 3]
# Out:
# /Users/yasutakenaoki/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   import sys
