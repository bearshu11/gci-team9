# %%
import pandas as pd
import numpy as np

# %%
test_df = pd.read_csv("../data/test.tsv", delimiter="\t")
before_target_user_ids = test_df[test_df['user_id'].map(lambda x: x[-1]) == 'D'].values.tolist()
target_user_ids = []
for item in before_target_user_ids:
    target_user_ids.append(item[0])
target_user_ids
# Out:
# ['0000231_D',
#  '0032126_D',
#  '0000515_D',
#  '0000548_D',
#  '0001211_D',
#  '0059931_D',
#  '0001789_D',
#  '0016920_D',
#  '0002637_D',
#  '0003457_D',
#  '0002757_D',
#  '0002804_D',
#  '0003280_D',
#  '0003283_D',
#  '0013905_D',
#  '0063594_D',
#  '0003726_D',
#  '0004149_D',
#  '0004589_D',
#  '0005826_D',
#  '0006167_D',
#  '0006388_D',
#  '0006816_D',
#  '0039443_D',
#  '0039194_D',
#  '0006845_D',
#  '0006938_D',
#  '0073279_D',
#  '0007107_D',
#  '0007139_D',
#  '0070532_D',
#  '0007182_D',
#  '0007424_D',
#  '0007585_D',
#  '0038772_D',
#  '0007962_D',
#  '0008990_D',
#  '0009280_D',
#  '0009903_D',
#  '0010011_D',
#  '0010158_D',
#  '0010267_D',
#  '0010530_D',
#  '0010843_D',
#  '0010855_D',
#  '0011196_D',
#  '0011300_D',
#  '0011711_D',
#  '0011805_D',
#  '0011883_D',
#  '0012382_D',
#  '0013086_D',
#  '0013375_D',
#  '0013516_D',
#  '0013630_D',
#  '0013866_D',
#  '0061610_D',
#  '0029986_D',
#  '0014389_D',
#  '0014405_D',
#  '0014470_D',
#  '0014513_D',
# ...

# %%
np.sum?
